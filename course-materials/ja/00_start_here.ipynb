# %% [markdown]
# # 第0章 — Python・プログラム・Python Lab
#
# **Moodle：** 第0章 — PythonとPython Labを始める
#
# **予想 → 実行 → 確認 → 変更 → 説明**の順で進めます。

# %% [markdown]
# ## プログラムが行うこと
#
# コンピュータは人の目的を推測せず、明示された命令を実行します。
#
# **入力 → メモリ上での処理 → 出力／永続的な保存**
#
# Pythonインタプリタがソースコードを読み取り実行します。文法が正しいか、実行できるか、結果が目的に合うかは異なる問いです。

# %% [markdown]
# ## 三つの実行方法
#
# - **Notebook（標準）：**説明、コード、結果を保存します。
# - **Console：**一行ずつ直ちに実行します。
# - **`.py`スクリプト：**保存した命令を通常は上から順に実行します。
#
# 値、変数、条件、繰り返し、関数は他言語にもつながります。翻訳方法、型の規則、メモリ管理は言語ごとに異なります。

# %% [markdown]
# ## 実行・変更・再実行
#
# 二行を予想し、**Shift+Enter**で実行し、挨拶と数値を変えて再実行します。

# %%
print("Python Labへようこそ！")
print(2 + 3)

# %% [markdown]
# ## Kernelの状態と保存ファイル
#
# Kernelは実行中の作業用メモリです。Notebookファイルは永続的な記録です。結果が分かりにくいときは、**Kernelを再起動してすべてのセルを実行**します。

# %% [markdown]
# ## エラーを読む
#
# 次の行のコメントを外し、最後の行を読み、閉じ引用符を加えて再実行します。

# %%
# print("この文字列は閉じていません)
print("修正完了")

# %% [markdown]
# ## Kernelの隠れた状態を体験する
#
# 次の二つのセルを上から順に実行します。Kernelを再起動し、二番目のセルだけを実行してください。`current_count`がまだ存在しないため、最後の`NameError`の行を読みます。最後に**Kernelを再起動して全セルを実行**し、初期状態から正しく動くことを確認します。

# %%
current_count = 18

# %%
print("現在の人数:", current_count)

# %% [markdown]
# ## 三つの異なる問題を区別する
#
# 壊れた行のコメントを一つずつ外します。閉じ引用符の不足は**文法の問題**、ゼロ除算は**実行時の問題**です。下の加算は動きますが、未使用席としては**誤った結果**です。コメントを元へ戻し、減算と比較して違いを説明してください。

# %%
# print("閉じ引用符がありません)
# print(10 / 0)
print("動くが誤った未使用席:", 40 + 30)
print("正しい未使用席:", 40 - 30)

# %% [markdown]
# ## 第0章を完了する
#
# 新しいMarkdownセルに、**Kernelメモリ上の現在値**、**保存済みNotebook**、**外部データファイル**のうち、Kernel再起動で消えるものと、ブラウザを閉じても残るものを説明します。
#
# 確認項目：
# - [ ] Codeセルを実行・変更し、Markdownの説明を追加した。
# - [ ] 文法、実行時、誤った結果の問題を区別した。
# - [ ] Kernelを再起動し、全セルを正常に実行した。
# - [ ] 保存し、閉じて、同じファイルを再度開いた。
#
# Python Lab自体に問題がある場合、別のPythonをインストールしたり共用パッケージを変更したりしません。活動名、最後のエラー行、直前の操作を記録し、講師またはサイト管理者へ相談します。

# %% [markdown]
# ## 保存して再開
#
# Markdownへ記録し、**Ctrl+S**で保存し、閉じて同じNotebookを再度開き、記録が残っていることを確認します。
