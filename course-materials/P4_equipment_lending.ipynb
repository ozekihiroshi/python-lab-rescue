# %% [markdown]
# # Project 4.5 — Community equipment lending desk
#
# Inspect the inventory and request CSVs, then complete the supplied starter. Submit only `equipment_lending.py`.

# %%
from pathlib import Path
import csv

project = Path.cwd() / "projects" / "equipment-lending"
inventory = project / "data" / "equipment_inventory.csv"
requests = project / "data" / "lending_requests.csv"
print("Project:", project)
print("Inventory found:", inventory.is_file())
print("Requests found:", requests.is_file())

# %% [markdown]
# ## 1. Inspect the source records
#
# The next cell is not data to copy into the program. Display it to understand opening state and the ordered work.

# %%
for label, path in [("OPENING INVENTORY", inventory), ("TODAY'S REQUESTS", requests)]:
    print("\n" + label)
    with path.open(newline="", encoding="utf-8") as handle:
        for row in csv.DictReader(handle):
            print(row)

# %% [markdown]
# ## 2. Complete the starter in stages
#
# Open `projects/equipment-lending/equipment_lending.py` from the file browser. Complete TODOs 1–6 (item), 7–12 (desk), then 13–16 (CSV and orchestration). Save with Ctrl+S after every stage.

# %% [markdown]
# ## 3. Run it yourself
#
# An incomplete-starter error is normal at first. A completed program displays six summary counts.

# %%
# !python projects/equipment-lending/equipment_lending.py

# %% [markdown]
# ## 4. Inspect both output CSVs
#
# Inspect these only after the preceding run succeeds. Rejected requests must remain in the result CSV.

# %%
for filename in ["equipment_inventory_after.csv", "lending_results.csv"]:
    path = project / "output" / filename
    print("\n" + filename)
    print(path.read_text(encoding="utf-8") if path.is_file() else "Not created yet")

# %% [markdown]
# ## 5. Automatic confirmation
#
# The checker also uses different IDs and a different request order. Repair from the first NG until the last line says `ALL TESTS PASSED`.

# %%
# !python projects/equipment-lending/check_equipment_lending.py

# %% [markdown]
# After completion, submit `equipment_lending.py` to Moodle. Do not submit sources, generated CSVs, or the checker.
