# %% [markdown]
# # Final project — From question to evidence
#
# **Moodle section:** Final project and reflection
#
# Use the course cycle: **Predict → Run → Check → Change → Explain**. Save before closing Python Lab; your notebook remains in your server workspace.

# %% [markdown]
# ## Planning record
#
# Write your question, data source and licence, data dictionary, expected measures, privacy decision, and validation plan before writing analysis code.

# %%
# Imports and source loading
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis sections
#
# Add separate cells for inspection, cleaning log, calculation, validation, table, chart, and interpretation.

# %%
# Analysis scaffold: replace this comment one tested stage at a time.

# %% [markdown]
# ## Final report
#
# 250–400 words containing one finding, numerical evidence, one limitation, a next question, and the AI-use declaration.

# %% [markdown]
# ## Learning record
#
# Before returning to Moodle, write down: (1) one result you predicted correctly, (2) one change you tested, and (3) one question or error you still have. Then complete the Moodle learning check.
